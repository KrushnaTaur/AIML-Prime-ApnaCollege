# %% [markdown]
# <a href="https://colab.research.google.com/github/KrushnaTaur/AIML-Prime-ApnaCollege/blob/main/Assignments/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Python Assignment - 1**

# %% [markdown]
# Q1. Write a program that asks the user for their name and age, then prints a sentence like: Hello Krushna, you are 20 years old!

# %%
name = input("Enter name: ")
age = int(input("Enter age: "))

print("Hello ", name+ ", you are ", age, " years old!")
# Out:
# Enter name: Krushna
# Enter age: 20
# Hello  Krushna, you are  20  years old!

# %% [markdown]
# Q2. Take two numbers as input from the user and print their sum, difference,
# product, and quotient.

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

sum = num1 + num2
difference = num1 - num2
product = num1 * num2
quotient = num1 / num2

print("Sum ", sum)
print("Difference ", difference)
print("Product ", product)
print("Quotient ",quotient)
# Out:
# Enter first number: 10
# Enter second number: 5
# Sum  15
# Difference  5
# Product  50
# Quotient  2.0

# %% [markdown]
# Q3. Ask the user to enter two integers and one float. Convert them all to floats and print their average.

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
num3 = float(input("Enter third number: "))

num1 = float(num1)
num2 = float(num2)

average = (num1+num2+num3)/ 3
print("The average of three numbers is: ", average)
# Out:
# Enter first number: 10
# Enter second number: 20
# Enter third number: 30
# The average of three numbers is:  20.0

# %% [markdown]
# Q4. The user enters a string containing a number (e.g. "45" ). Convert it to:
#
# • an integer
#
# • a float
#
# • a string again
#
# Print all three values with their types.

# %%
num_str = input("Enter a number: ")

num_int = int(num_str)
num_float = float(num_str)
num_str = str(num_int)

print(num_int, type(num_int))
print(num_float, type(num_float))
print(num_str, type(num_str))
# Out:
# Enter a number: 10
# 10 <class 'int'>
# 10.0 <class 'float'>
# 10 <class 'str'>

# %% [markdown]
# Q5. Evaluate and print the result of the following expression:
# x = 10 + 3 * 2 ** 2

# %%
x = 10 + 3 * 2 ** 2

print(x)
# Out:
# 22

# %% [markdown]
# Q6. Write a program to swap values of two numbers entered by the user.

# %%
a = int(input("Enter A : "))
b = int(input("Enter B : "))

'''
temp = a
a = b
b = temp
'''

a, b = b, a

print("After swapping: ")
print("Value of A: ", a)
print("Value of B: ", b)
# Out:
# Enter A : 1
# Enter B : 2
# After swapping:
# Value of A:  2
# Value of B:  1

# %% [markdown]
# Q7. Ask the user for a temperature in Celsius (string input). Convert it to float, then calculate and print temperature in Fahrenheit.
#
# Conversion formula: FahrenheitTemp = (CelsiusTemp ∗ (9/5)) +
# 32

# %%
temp = input("Enter temperature in Celsius: ")

temp = float(temp)

fahrenheit_temp = (temp * (9/5)) + 32

print("Temperature in Fahrenheit: ", fahrenheit_temp)
# Out:
# Enter temperature in Celsius: 25
# Temperature in Fahrenheit:  77.0

# %% [markdown]
# Q8. Take the radius (r) as user input and print the area.
#
# Use the formula: Area = π * r2
# (value of π = 3.14)

# %%
radius = int(input("Enter radius: "))

area = 3.14 * radius * radius

print("Area of circle: ", area)
# Out:
# Enter radius: 5
# Area of circle:  78.5

# %% [markdown]
# Q9. Ask the user for: Principal (P), Rate (R), Time (T). Convert all to and
# compute simple interest:
# SI = (P ∗ R ∗ T )/100

# %%
p = float(input("Enter principal: "))
r = float(input("Enter rate: "))
t = float(input("Enter time: "))

si = (p * r * t) / 100

print("Simple Interest: ", si)
# Out:
# Enter principal: 100
# Enter rate: 2
# Enter time: 12
# Simple Interest:  24.0

# %% [markdown]
# Q10. Take a decimal number as input (like 45.78 ) and output its:
#
# • integer part - 45
#
# • fractional part - .78

# %%
num = float(input("Enter a decimal number: "))

integer_part = int(num)
fractional_part = num - integer_part

print("Integer part: ", integer_part)
print("Fractional part: ", fractional_part)
# Out:
# Enter a decimal number: 17.18
# Integer part:  17
# Fractional part:  0.17999999999999972
