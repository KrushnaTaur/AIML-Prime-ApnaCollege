# %%
import pandas as pd

# %%
df = pd.read_csv("globalAirQuality.csv")

df
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
df.head()
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 0  2025-11-04 18:25:17.554219      US  New York    40.713    -74.006  50.295
# 1  2025-11-04 19:25:17.554219      US  New York    40.713    -74.006  32.083
# 2  2025-11-04 20:25:17.554219      US  New York    40.713    -74.006  42.250
# 3  2025-11-04 21:25:17.554219      US  New York    40.713    -74.006  30.403
# 4  2025-11-04 22:25:17.554219      US  New York    40.713    -74.006  21.083
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 0  108.938  27.998  6.539  52.568  1.096  108       18.504    70.168
# 1   63.043  36.120  4.021  43.536  1.075   90        5.838    80.088
# 2   82.553  26.935  9.538  23.320  0.977   84       31.833    62.783
# 3   79.951  63.536  7.609  31.369  0.230  158       23.140    89.153
# 4   66.423  38.997  6.919  45.615  1.085   97       13.632    76.499
#
#    wind_speed
# 0       3.725
# 1       8.969
# 2       9.650
# 3       8.956
# ...

# %%
df.describe()
# Out:
#            latitude     longitude          pm25          pm10           no2  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean      23.065980     37.655560     40.369131     70.152228     32.055176
# std       26.156536     78.600701     17.647450     24.999440     13.820680
# min      -37.814000   -123.121000      0.025000      0.061000      0.013000
# 25%       12.972000      2.352000     27.904500     53.125500     22.362500
# 50%       29.232000     42.146000     40.286500     69.961000     32.019500
# 75%       41.008000    103.820000     52.436250     87.256500     41.364250
# max       60.170000    174.763000    115.683000    161.810000     90.019000
#
#                 so2            o3            co           aqi   temperature  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean       6.035508     48.065100      0.800595    104.645556     21.510251
# ...

# %%
# Selecting data

df["country"]
# Out:
# 0        US
# 1        US
# 2        US
# 3        US
# 4        US
#          ..
# 17995    CH
# 17996    CH
# 17997    CH
# 17998    CH
# 17999    CH
# Name: country, Length: 18000, dtype: object

# %%
df[["city", "aqi"]]
# Out:
#            city  aqi
# 0      New York  108
# 1      New York   90
# 2      New York   84
# 3      New York  158
# 4      New York   97
# ...         ...  ...
# 17995    Zurich  103
# 17996    Zurich  105
# 17997    Zurich  122
# 17998    Zurich   95
# 17999    Zurich   88
#
# [18000 rows x 2 columns]

# %%
df.loc[0]
# Out:
# timestamp      2025-11-04 18:25:17.554219
# country                                US
# city                             New York
# latitude                           40.713
# longitude                         -74.006
# pm25                               50.295
# pm10                              108.938
# no2                                27.998
# so2                                 6.539
# o3                                 52.568
# co                                  1.096
# aqi                                   108
# temperature                        18.504
# humidity                           70.168
# wind_speed                          3.725
# Name: 0, dtype: object

# %%
df.loc[6:9]
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 6  2025-11-05 00:25:17.554219      US  New York    40.713    -74.006  77.690
# 7  2025-11-05 01:25:17.554219      US  New York    40.713    -74.006  57.816
# 8  2025-11-05 02:25:17.554219      US  New York    40.713    -74.006  60.914
# 9  2025-11-05 03:25:17.554219      US  New York    40.713    -74.006  16.464
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 6   65.198  20.302  7.641  62.687  0.734  155       36.729    47.651
# 7  111.709  34.533  6.945  41.304  0.771  115       37.891    53.314
# 8   44.775  40.936  6.779  36.751  1.014  121       24.092    48.148
# 9   76.631  28.119  8.561  79.467  1.081   76       11.490    29.403
#
#    wind_speed
# 6       4.542
# 7       7.605
# 8       8.686
# 9       3.762

# %%
df.iloc[1]
# Out:
# timestamp      2025-11-04 19:25:17.554219
# country                                US
# city                             New York
# latitude                           40.713
# longitude                         -74.006
# pm25                               32.083
# pm10                               63.043
# no2                                 36.12
# so2                                 4.021
# o3                                 43.536
# co                                  1.075
# aqi                                    90
# temperature                         5.838
# humidity                           80.088
# wind_speed                          8.969
# Name: 1, dtype: object

# %%
df.iloc[6:9]
# Out:
#                     timestamp country      city  latitude  longitude    pm25  \
# 6  2025-11-05 00:25:17.554219      US  New York    40.713    -74.006  77.690
# 7  2025-11-05 01:25:17.554219      US  New York    40.713    -74.006  57.816
# 8  2025-11-05 02:25:17.554219      US  New York    40.713    -74.006  60.914
#
#       pm10     no2    so2      o3     co  aqi  temperature  humidity  \
# 6   65.198  20.302  7.641  62.687  0.734  155       36.729    47.651
# 7  111.709  34.533  6.945  41.304  0.771  115       37.891    53.314
# 8   44.775  40.936  6.779  36.751  1.014  121       24.092    48.148
#
#    wind_speed
# 6       4.542
# 7       7.605
# 8       8.686

# %%
df.loc[0:2, ["city", "aqi"]]
# Out:
#        city  aqi
# 0  New York  108
# 1  New York   90
# 2  New York   84

# %%
df.columns
# Out:
# Index(['timestamp', 'country', 'city', 'latitude', 'longitude', 'pm25', 'pm10',
#        'no2', 'so2', 'o3', 'co', 'aqi', 'temperature', 'humidity',
#        'wind_speed'],
#       dtype='object')

# %%
df.iloc[0:3, 1:5]
# Out:
#   country      city  latitude  longitude
# 0      US  New York    40.713    -74.006
# 1      US  New York    40.713    -74.006
# 2      US  New York    40.713    -74.006

# %%
df.at[0, "city"]
# Out:
# 'New York'

# %%
df.iat[0,2]
# Out:
# 'New York'

# %%
cities = df["city"].copy()
cities[1] = "Mumbai"

cities
# Out:
# 0        New York
# 1          Mumbai
# 2        New York
# 3        New York
# 4        New York
#            ...
# 17995      Zurich
# 17996      Zurich
# 17997      Zurich
# 17998      Zurich
# 17999      Zurich
# Name: city, Length: 18000, dtype: object

# %%
#filtering of data

df[df["aqi"] > 205]
# Out:
#                         timestamp country      city  latitude  longitude  \
# 745    2025-11-05 19:25:17.554219      GB    London    51.507     -0.128
# 12956  2025-11-19 14:25:17.554219      NZ  Auckland   -36.848    174.763
# 14555  2025-11-11 05:25:17.554219      PH    Manila    14.600    120.984
# 17529  2025-11-15 03:25:17.554219      FI  Helsinki    60.170     24.938
#
#           pm25    pm10     no2    so2      o3     co  aqi  temperature  \
# 745    107.144  43.819  13.389  4.601  21.680  0.890  214       19.055
# 12956   44.824  66.657  90.019  3.637  41.311  0.849  225       14.872
# 14555  103.023  66.678  43.284  2.167  48.250  0.849  206       11.027
# 17529  115.683  81.714  54.764  6.687  39.552  0.685  231       25.795
#
#        humidity  wind_speed
# 745      66.245       1.637
# 12956    63.319       0.958
# 14555    63.522       7.635
# 17529    87.839       6.705

# %%
df[(df["aqi"] > 195) & (df["temperature"] > 30)]
# Out:
#                         timestamp country         city  latitude  longitude  \
# 3115   2025-11-14 13:25:17.554219      MX  Mexico City    19.433    -99.133
# 11564  2025-11-06 14:25:17.554219      ID      Jakarta    -6.209    106.846
# 12776  2025-11-12 02:25:17.554219      NZ     Auckland   -36.848    174.763
# 17458  2025-11-12 04:25:17.554219      FI     Helsinki    60.170     24.938
#
#          pm25    pm10     no2    so2      o3     co  aqi  temperature  \
# 3115   98.327  97.741  23.343  8.865  46.702  0.713  196       30.738
# 11564  40.484  79.717  79.303  7.311  30.245  0.702  198       36.710
# 12776  58.672  99.358  78.586  4.415  67.490  1.449  196       34.282
# 17458  14.329  51.173  81.111  7.725  61.160  1.383  202       34.420
#
#        humidity  wind_speed
# 3115     66.421       1.256
# 11564    78.685       4.315
# 12776    55.299       9.528
# 17458    26.061       3.771

# %%
df[ df["aqi"] > 205] [["city", "aqi"]]
# Out:
#            city  aqi
# 745      London  214
# 12956  Auckland  225
# 14555    Manila  206
# 17529  Helsinki  231

# %%
aqi_data = df[(df["aqi"] > 195) & (df["temperature"] > 30)] [["city", "aqi"]]

aqi_data
# Out:
#               city  aqi
# 3115   Mexico City  196
# 11564      Jakarta  198
# 12776     Auckland  196
# 17458     Helsinki  202

# %%
aqi_data.iloc[0]
# Out:
# city    Mexico City
# aqi             196
# Name: 3115, dtype: object

# %%
aqi_data.loc[12776]
# Out:
# city    Auckland
# aqi          196
# Name: 12776, dtype: object

# %%
#Query method

df.query("aqi > 203 & temperature > 15")
# Out:
#                         timestamp country      city  latitude  longitude  \
# 745    2025-11-05 19:25:17.554219      GB    London    51.507     -0.128
# 8941   2025-11-17 07:25:17.554219      JP     Osaka    34.694    135.502
# 17529  2025-11-15 03:25:17.554219      FI  Helsinki    60.170     24.938
#
#           pm25    pm10     no2    so2      o3     co  aqi  temperature  \
# 745    107.144  43.819  13.389  4.601  21.680  0.890  214       19.055
# 8941   102.142  95.204  41.688  7.806  28.951  0.753  204       15.277
# 17529  115.683  81.714  54.764  6.687  39.552  0.685  231       25.795
#
#        humidity  wind_speed
# 745      66.245       1.637
# 8941     76.131       4.586
# 17529    87.839       6.705

# %%
df.query("aqi > 203 & temperature > 15") [["city", "aqi"]]
# Out:
#            city  aqi
# 745      London  214
# 8941      Osaka  204
# 17529  Helsinki  231

# %%
aqi_val = 200
df.query("aqi > @aqi_val & temperature > 15") [["city", "aqi"]]
# Out:
#            city  aqi
# 745      London  214
# 8941      Osaka  204
# 17458  Helsinki  202
# 17529  Helsinki  231
# 17815    Zurich  203
