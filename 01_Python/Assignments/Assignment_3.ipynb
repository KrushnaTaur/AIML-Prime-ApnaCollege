# %% [markdown]
# **Assignment 3**

# %% [markdown]
# Q1. Ask the user for a string and check whether it is a palindrome or not.
# A palindrome is a string which is same when we read it forward & backward. Eg - “madam”, “racecar” etc.

# %%
text = input("Enter a string: ")

rev = ""

for ch in text:
    rev = ch + rev

if text == rev:
    print("Palindrome")
else:
    print("Not a palindrome")
# Out:
# Enter a string: madam
# Palindrome

# %% [markdown]
# Q2.Given a list of integers compute the average of all numbers in the list.

# %%
n = int(input("Enter number of elements: "))

total = 0

for i in range(n):
    num = int(input("Enter number: "))
    total += num

average = total / n

print("Average:", average)
# Out:
# Enter number of elements: 3
# Enter number: 15
# Enter number: 52
# Enter number: 32
# Average: 33.0

# %% [markdown]
# Q3. Input two lists of integers from the user. Merge them into one list and sort the result.
#
# Eg - list1 = [1, 2, 7] , list2 = [2, 4, 5]
#
# result = [1, 2, 3, 54, 5, 7]

# %%
n1 = int(input("Enter number of elements in first list: "))
list1 = []

for i in range(n1):
    list1.append(int(input("Enter element: ")))

n2 = int(input("Enter number of elements in second list: "))
list2 = []

for i in range(n2):
    list2.append(int(input("Enter element: ")))

result = list1 + list2

result.sort()

print("Merged & Sorted List:", result)
# Out:
# Enter number of elements in first list: 3
# Enter element: 1
# Enter element: 2
# Enter element: 7
# Enter number of elements in second list: 3
# Enter element: 2
# Enter element: 4
# Enter element: 5
# Merged & Sorted List: [1, 2, 2, 4, 5, 7]

# %% [markdown]
# Q4. Given a tuple of integers, create:
#
# • A tuple of all even numbers
#
# • A tuple of all odd numbers

# %%
t = tuple(int(input("Enter number: "))
for _ in range(int(input("How many numbers? "))))

even = ()
odd = ()

for num in t:
    if num % 2 == 0:
        even += (num,)
    else:
        odd += (num,)

print("Original tuple:", t)
print("Even numbers tuple:", even)
print("Odd numbers tuple:", odd)
# Out:
# How many numbers? 6
# Enter number: 1
# Enter number: 2
# Enter number: 3
# Enter number: 4
# Enter number: 5
# Enter number: 6
# Original tuple: (1, 2, 3, 4, 5, 6)
# Even numbers tuple: (2, 4, 6)
# Odd numbers tuple: (1, 3, 5)

# %% [markdown]
# Q5. Create a dictionary where:
#
# • Keys = student names
#
# • Values = marks (integer)
#
# Write a menu-based program where user presses a key (ʼAʼ, ‘Bʼ, ‘Cʼ, ‘Dʼ)
# depending on the operation they want to perform on the dictionary:
# 1. A - Add a student
#
# 2. B - Update marks
#
# 3. C - Search for a student
#
# 4. D - Display all students and marks

# %%
students = {}

while True:
    print("\nA - Add a student")
    print("B - Update marks")
    print("C - Search for a student")
    print("D - Display all students and marks")
    print("E - Exit")

    choice = input("Enter your choice: ").upper()

    if choice == "A":
        name = input("Enter student name: ")
        marks = int(input("Enter marks: "))
        students[name] = marks
        print("Student added successfully")

    elif choice == "B":
        name = input("Enter student name to update: ")
        if name in students:
            marks = int(input("Enter new marks: "))
            students[name] = marks
            print("Marks updated")
        else:
            print("Student not found")

    elif choice == "C":
        name = input("Enter student name to search: ")
        if name in students:
            print("Marks:", students[name])
        else:
            print("Student not found")

    elif choice == "D":
        if not students:
            print("No students found")
        else:
            for name, marks in students.items():
                print(name, ":", marks)

    elif choice == "E":
        print("Exiting program")
        break

    else:
        print("Invalid choice")
# Out:
# A - Add a student
# B - Update marks
# C - Search for a student
# D - Display all students and marks
# E - Exit
# Enter your choice: A
# Enter student name: Krushna
# Enter marks: 90
# Student added successfully
#
# A - Add a student
# B - Update marks
# C - Search for a student
# D - Display all students and marks
# E - Exit
# Enter your choice: D
# Krushna : 90
#
# A - Add a student
# B - Update marks
# C - Search for a student
# D - Display all students and marks
# E - Exit
# Enter your choice: E
# Exiting program

# %% [markdown]
# Q6. Given a list of words:
#
# words = ["apple", "banana", "kiwi", "cherry", "mango"]
#
# Create a dictionary that maps each word to its length.
#
# Example: {"apple": 5, "banana": 6, "kiwi": 4, ...}

# %%
words = ["apple", "banana", "kiwi", "cherry", "mango"]

word_length = {}

for word in words:
    word_length[word] = len(word)

print(word_length)
# Out:
# {'apple': 5, 'banana': 6, 'kiwi': 4, 'cherry': 6, 'mango': 5}

# %% [markdown]
# Q7. Write a program that takes a string from the user and prints the number of
# spaces in the string.

# %%
text = input("Enter a string: ")

count = 0

for ch in text:
    if ch == " ":
        count += 1

print("Number of spaces:", count)
# Out:
# Enter a string: Hello my name is Krushna
# Number of spaces: 4

# %% [markdown]
# Q8. Write a program to check whether two lists share no common elements.
#
# share no common elements list1 = [1, 2, 3, 4] list2 = [5, 6, 7, 8]
#
# share common elements list1 = [1, 2, 3] list2 = [3, 4]

# %%
list1 = list(map(int, input("Enter elements of first list: ").split()))
list2 = list(map(int, input("Enter elements of second list: ").split()))

set1 = set(list1)
set2 = set(list2)

if set1.isdisjoint(set2):
    print("The two lists share NO common elements")
else:
    print("The two lists share COMMON elements")
# Out:
# Enter elements of first list: 1 2 3
# Enter elements of second list: 3 4
# The two lists share COMMON elements

# %% [markdown]
# Q9. Given a list, print all elements that appear more than once in the list.

# %%
numbers = list(map(int, input("Enter elements of the list: ").split()))

seen = set()
duplicates = set()

for num in numbers:
    if num in seen:
        duplicates.add(num)
    else:
        seen.add(num)

if duplicates:
    print("Elements appearing more than once:", duplicates)
else:
    print("No duplicate elements found")
# Out:
# Enter elements of the list: 1 2 3 4 5 1 2 5
# Elements appearing more than once: {1, 2, 5}

# %% [markdown]
# Q10. Ask the user for a string and print:
#
# • All unique characters
#
# • The count of unique characters

# %%
text = input("Enter a string: ")

unique_chars = set(text)

print("Unique characters:")
for ch in unique_chars:
    print(ch)

print("Count of unique characters:", len(unique_chars))
# Out:
# Enter a string: hello world
# Unique characters:
# e
# w
# r
# o
# l
#
# d
# h
# Count of unique characters: 8
